# %% [markdown]
# # Assignment 8 - Deep Learning for NLP
#
# [Dataset](https://drive.google.com/file/d/1HEcyWf93HxbJeC5kE0nLQH8fPevEiUhM/view?usp=sharing)

# %%
import numpy as np
import pandas as pd
import re

import gensim
from gensim.models import Word2Vec

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

pd.set_option('display.max_colwidth',None)

# %% [markdown]
# 1. Importing dataset

# %%
import chardet

# Detect the encoding of the CSV file
with open('/content/drive/MyDrive/Data/tweet_product_company.csv', 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']

print(encoding)
# Out:
# MacRoman

# %%
# Read the CSV file with the detected encoding
data = pd.read_csv('/content/drive/MyDrive/Data/tweet_product_company.csv', encoding=encoding)

# %%
data.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %%
data.columns
# Out:
# Index(['tweet_text', 'emotion_in_tweet_is_directed_at',
#        'is_there_an_emotion_directed_at_a_brand_or_product'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# tweet_text                                               1
# emotion_in_tweet_is_directed_at                       5802
# is_there_an_emotion_directed_at_a_brand_or_product       0
# dtype: int64

# %%
data['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts()
# Out:
# is_there_an_emotion_directed_at_a_brand_or_product
# No emotion toward brand or product    5389
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9093 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   tweet_text                                          9092 non-null   object
#  1   emotion_in_tweet_is_directed_at                     3291 non-null   object
#  2   is_there_an_emotion_directed_at_a_brand_or_product  9093 non-null   object
# dtypes: object(3)
# memory usage: 213.2+ KB

# %% [markdown]
# 2. Creating 'df' with necessary attributes from 'data'

# %%
df = data[['tweet_text','is_there_an_emotion_directed_at_a_brand_or_product']]

# %%
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %% [markdown]
# 3. Renaming columns in df

# %%
new_columns = ['tweet','sentiment']
df.columns = new_columns
df.head()
# Out:
#                                                                                                                                          tweet  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#           sentiment
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %% [markdown]
# 4. Mapping 'sentiment' values to numeric values

# %%
# Define the mapping of sentiment values to numeric values
sentiment_mapping = {
    "No emotion toward brand or product": 0,
    "Positive emotion": 1,
    "Negative emotion": -1,
    "I can't tell": 0
}

# Replace values in the 'sentiment' column using the mapping
df['sentiment'] = df['sentiment'].replace(sentiment_mapping)
df.head()
# Out:
# <ipython-input-83-648ac57dc641>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = df['sentiment'].replace(sentiment_mapping)
#                                                                                                                                          tweet  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#    sentiment
# 0         -1
# 1          1
# 2          1
# 3         -1
# 4          1

# %% [markdown]
# 5. Checking for empty cells

# %%
df.isna().sum()
# Out:
# tweet        1
# sentiment    0
# dtype: int64

# %% [markdown]
# 6. Dropping empties

# %%
df = df.dropna()
df.reset_index(drop=True, inplace=True)
df.isna().sum()
# Out:
# tweet        0
# sentiment    0
# dtype: int64

# %%
df.head()
# Out:
#                                                                                                                                          tweet  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#    sentiment
# 0         -1
# 1          1
# 2          1
# 3         -1
# 4          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9092 entries, 0 to 9091
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      9092 non-null   object
#  1   sentiment  9092 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 142.2+ KB

# %% [markdown]
# 7. Preprocessing 'tweets' using gensim's simple_preprocessor

# %%
df['cleaned_text'] = df['tweet'].apply(lambda x:gensim.utils.simple_preprocess(x))
df.head()
# Out:
#                                                                                                                                          tweet  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#    sentiment  \
# 0         -1
# 1          1
# 2          1
# 3         -1
# 4          1
#
#                                                                                                                                                     cleaned_text
# 0                                    [wesley, have, iphone, after, hrs, tweeting, at, rise_austin, it, was, dead, need, to, upgrade, plugin, stations, at, sxsw]
# 1  [jessedee, know, about, fludapp, awesome, ipad, iphone, app, that, you, ll, likely, appreciate, for, its, design, also, they, re, giving, free, ts, at, sxsw]
# 2                                                                        [swonderlin, can, not, wait, for, ipad, also, they, should, sale, them, down, at, sxsw]
# 3                                                                         [sxsw, hope, this, year, festival, isn, as, crashy, as, this, year, iphone, app, sxsw]
# 4                       [sxtxstate, great, stuff, on, fri, sxsw, marissa, mayer, google, tim, reilly, tech, books, conferences, amp, matt, mullenweg, wordpress]

# %% [markdown]
# 8. Vocabulary size

# %%
from collections import Counter

words_count = Counter([word for text in df['cleaned_text'] for word in text])
vocab_size = len(words_count)
print("Vocabulary Size:", vocab_size)
# Out:
# Vocabulary Size: 9333

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# 9. Tokenization
#
#   1. Creates a `Tokenizer` object with the vocabulary size set to the number of unique words in the corpus.
#   2. Fits the tokenizer on the `cleaned_text` column of the `df` dataframe. This creates a mapping between words and integers.
#   3. Converts the `cleaned_text` column into a list of sequences of integers, where each integer represents a word in the vocabulary.

# %%
# Tokenization
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(df['cleaned_text'])
X_sequences = tokenizer.texts_to_sequences(df['cleaned_text'])

# %% [markdown]
# 10. Padding
#
# Pads the sequences to a maximum length of 100, ensuring that all sequences have the same length. This is necessary for feeding the data into a neural network.
#
# This preprocessed data can now be used to train a machine learning model for sentiment analysis.

# %%
# Padding sequences
X_padded = pad_sequences(X_sequences, maxlen=100, padding='post', truncating='post')

# %% [markdown]
# 11. Encoding the labels using LabelEncoder()

# %%
# One-Hot Encoding for sentiment labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(df['sentiment'])

# %% [markdown]
# 12. Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# 13. Building model

# %%
from keras.layers import Dense, LSTM, Embedding
from keras.models import Sequential

# %%
from keras.layers import Dropout

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=5, input_length=100))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(60))
model.add(Dense(50, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 5)            46665
#
#  lstm_4 (LSTM)               (None, 100, 50)           11200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_5 (LSTM)               (None, 60)                26640
#
#  dense_4 (Dense)             (None, 50)                3050
#
#  dense_5 (Dense)             (None, 3)                 153
#
# =================================================================
# Total params: 87708 (342.61 KB)
# Trainable params: 87708 (342.61 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 14. Training the model

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=128, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 57/57 [==============================] - 17s 290ms/step - loss: 0.8382 - accuracy: 0.6121 - val_loss: 0.8540 - val_accuracy: 0.6003
# Epoch 2/10
# 57/57 [==============================] - 18s 311ms/step - loss: 0.8383 - accuracy: 0.6121 - val_loss: 0.8532 - val_accuracy: 0.6003
# Epoch 3/10
# 57/57 [==============================] - 19s 323ms/step - loss: 0.8380 - accuracy: 0.6121 - val_loss: 0.8538 - val_accuracy: 0.6003
# Epoch 4/10
# 57/57 [==============================] - 20s 360ms/step - loss: 0.8382 - accuracy: 0.6121 - val_loss: 0.8530 - val_accuracy: 0.6003
# Epoch 5/10
# 57/57 [==============================] - 16s 288ms/step - loss: 0.8382 - accuracy: 0.6121 - val_loss: 0.8533 - val_accuracy: 0.6003
# Epoch 6/10
# 57/57 [==============================] - 17s 293ms/step - loss: 0.8381 - accuracy: 0.6121 - val_loss: 0.8530 - val_accuracy: 0.6003
# Epoch 7/10
# 57/57 [==============================] - 18s 319ms/step - loss: 0.8382 - accuracy: 0.6121 - val_loss: 0.8535 - val_accuracy: 0.6003
# Epoch 8/10
# 57/57 [==============================] - 16s 288ms/step - loss: 0.8381 - accuracy: 0.6121 - val_loss: 0.8530 - val_accuracy: 0.6003
# Epoch 9/10
# 57/57 [==============================] - 16s 288ms/step - loss: 0.8382 - accuracy: 0.6121 - val_loss: 0.8535 - val_accuracy: 0.6003
# Epoch 10/10
# 57/57 [==============================] - 16s 285ms/step - loss: 0.8382 - accuracy: 0.6121 - val_loss: 0.8541 - val_accuracy: 0.6003
